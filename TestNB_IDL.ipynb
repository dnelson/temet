# %% [markdown]
# ## IDL Kernel Test

# %%
a=1
print,a
# Out:
#        1
# % DEVICE: Unable to connect to X Windows display: :0.0
# % DEVICE: Unable to open X Windows display.
#           Is your DISPLAY environment variable set correctly?
# % Execution halted at: $MAIN$              3 /n/home07/dnelson/tmpqrCsEO

# %%
print,a
# Out:
#        1
# % DEVICE: Unable to connect to X Windows display: :0.0
# % DEVICE: Unable to open X Windows display.
#           Is your DISPLAY environment variable set correctly?
# % Execution halted at: $MAIN$              2 /n/home07/dnelson/tmpToPG_u

# %%
!inline=1
# Out:
# % DEVICE: Unable to connect to X Windows display: :0.0
# % DEVICE: Unable to open X Windows display.
#           Is your DISPLAY environment variable set correctly?
# % Execution halted at: $MAIN$              2 /n/home07/dnelson/tmpmJmwd5

# %%
x = 2*!PI*0.01*indgen(100)
y1 = sin(x)
y2 = cos(x)
loadct,39
window,xsize=800,ysize=500
plot,x,y1,title='Trig Functions',xtitle='Radians',ytitle='Amplitude',xrange=[0,6],charsize=1.5,background=255,color=0
oplot,x,y2,color=50
# Out:
# % WINDOW: Unable to connect to X Windows display: :0.0
# % WINDOW: Unable to open X Windows display.
#             Is your DISPLAY environment variable set correctly?
# % Execution halted at: $MAIN$              4 /n/home07/dnelson/tmpYO0lFn
